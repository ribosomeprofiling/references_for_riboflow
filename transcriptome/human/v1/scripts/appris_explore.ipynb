# %% [markdown]
# # SUBSETTING HUMAN TRANSCRIPTOME

# %% [markdown]
# We explore human transcriptome, coming from
# [APPRIS](http://appris-tools.org/)
# principal isoforms, and do some sanity checks. Based on our observatioons, we make decisions about which transcripts to exclude.

# %% [markdown]
# Note that we are inside the scripts folder and need to setup our paths accordingly.

# %%
! ls ..
# Out:
# raw  riboflow_annot_and_ref  scripts

# %% [markdown]
# To start, we include our library folder first. Make sure it exists in two levels up

# %%
import sys
sys.path.insert(0, '../../../..')
import gzip

from collections import defaultdict

import ref_lib
from ref_lib.Fasta import FastaFile, FastaEntry
from ref_lib.GTF import GTFfile, GTFEntry, get_gtf_contents

# %% [markdown]
# Here are the reference files we will be using:

# %%
transcripts_fasta = "../raw/sequence/gencode.v29.transcripts.fa.gz"
gencode_gtf       = "../raw/annotation/gencode.v29.annotation.gtf.gz"
appris_file       = "../raw/annotation/appris_data.principal.txt.gz"

# %% [markdown]
# Let's check the documentation and see what the output of get_gtf_contents is like

# %%
help(get_gtf_contents)
# Out:
# Help on function get_gtf_contents in module ref_lib.GTF:
#
# get_gtf_contents(gtf_file)
#     Reads a gtf file into a dictionary.
#
#     NOTE 1:
#     We tested this on encode gtf file.
#     Some unexpected behavior might occur on GTF files from other sources.
#
#     NOTE 2:
#     For compatibility reasons, in gene_id and transcript_id, we are removing the part after
#     ".". So, for example, ENSG00000178199.13 becomes ENSG00000178199
#
#     It returns a dictionary where its keys are gene ids and values are again (sub)dictionaries
#     where each (sub dictionary is of the form)
#         transcript_id -> { "exons": list(), "CDS": list(), "strand": k.strand,
#                            "start": k.start, "end": k.end, length: int}
#
#     Later when we want to determine relative UTR, CDS coordinates  etc.
#     We can place them in these (sub)dictionaries

# %% [markdown]
# GENCODE gtf contents are stored in a dictionary. It might take a while to read all gtf:

# %%
gtf_all = get_gtf_contents( gencode_gtf )

# %% [markdown]
# Random Two entries from the gtf contents:

# %%
list(gtf_all.items())[1000:1002]
# Out:
# [('ENSG00000162512',
#   {'ENST00000336798': {'exons': [(30876552, 30878740),
#      (30874297, 30874588),
#      (30869467, 30873377)],
#     'CDS': [(30876552, 30877247, 0),
#      (30874297, 30874588, 1),
#      (30873214, 30873377, 2)],
#     'strand': '-',
#     'start': 30869467,
#     'end': 30878740,
#     'gene_type': 'protein_coding',
#     'length': 6392},
#    'ENST00000339394': {'exons': [(30908449, 30908761),
#      (30878623, 30878740),
#      (30876552, 30877165),
#      (30874297, 30874588),
#      (30873135, 30873377)],
#     'CDS': [(30908449, 30908586, 0),
#      (30878623, 30878740, 1),
#      (30876552, 30877165, 2),
#      (30874297, 30874588, 3),
#      (30873214, 30873377, 4)],
#     'strand': '-',
#     'start': 30873135,
#     'end': 30908761,
#     'gene_type': 'protein_coding',
#     'length': 1580},
#    'ENST00000471567': {'exons': [(30881358, 30881429),
#      (30878623, 30878740),
#      (30876767, 30877165)],
#     'CDS': [],
#     'strand': '-',
#     'start': 30876767,
#     'end': 30881429,
#     'gene_type': 'protein_coding',
#     'length': 589},
#    'ENST00000487984': {'exons': [(30880602, 30880769),
#      (30879977, 30880014),
#      (30878929, 30879012),
#      (30878676, 30878740)],
#     'CDS': [],
#     'strand': '-',
#     'start': 30878676,
#     'end': 30880769,
#     'gene_type': 'protein_coding',
#     'length': 355}}),
#  ('ENSG00000266210',
#   {'ENST00000578099': {'exons': [(30918469, 30918735)],
#     'CDS': [],
#     'strand': '-',
#     'start': 30918469,
#     'end': 30918735,
#     'gene_type': 'misc_RNA',
#     'length': 267}})]

# %% [markdown]
# We define the functions to extract CDS and UTR coordinates relative ro the transcript start.
# These care stored in the gtf_all dictionary with "bed_" prefix.

# %%
def _find_rel_cds_end_coords( exon_list, cds_contents, coord_type, strand ):
    """
    Returns the start or end of the CDS 0-based bed format
    So the start position is included and end position is excluded
    """    
    # c is the corresponding_exon_index to the cds chunk
    
    if coord_type == "start":
        cds_chunk = cds_contents[0]
        c = cds_chunk[2]
        if strand == "+":
            this_sum = cds_chunk[0] - exon_list[c][0]
        else:
            this_sum = exon_list[c][1] - cds_chunk[1]
    else:
        cds_chunk = cds_contents[-1]
        c = cds_chunk[2]
        this_sum = (cds_chunk[1] - cds_chunk[0]) + 1
        
        if len(cds_contents) == 1:
            if strand == "+":
                this_sum += cds_chunk[0]  - exon_list[c][0]  
            else:
                this_sum += exon_list[c][1] - cds_chunk[1]
        """
        Delete this later!!!
        if strand == "+":
            this_sum = (cds_chunk[1] - cds_chunk[0]) + 1
        else:
            this_sum = cds_chunk[0] - exon_list[c][0]
        """
    for e in exon_list[:c]:
        this_sum += (e[1] - e[0]) + 1
        
    return this_sum


def find_rel_utr_cds_positions( genes_dict ):
    """
    For each transcri,pt, the first nucleotide (of the transcript) has position 0
    the coordinates are in BED stye
    so For A,B 
    A: start, is INCLUDED
    B: end, is EXCLUDED
    The coordinates have the _bed prefix and they are stored in
    the corresponding transcript dictionary
    """
    # 
    # 0-based and end coordinate is excluded
    # 
    for g_name, transcripts in genes_dict.items():
    
        for t_name, t_contents in transcripts.items():
            CDS_contents = t_contents.get("CDS", list())
            if len(CDS_contents) == 0:
                continue

            cds_rel_start = \
                _find_rel_cds_end_coords( t_contents["exons"], CDS_contents, "start", t_contents["strand"]   )
            cds_rel_end = \
                _find_rel_cds_end_coords( t_contents["exons"], CDS_contents, "end", t_contents["strand"] )
        
            t_length = t_contents["length"]
                
            t_contents["bed_CDS"] = ( cds_rel_start, cds_rel_end )
            if cds_rel_start > 0:
                t_contents["bed_UTR_5"] = (0, cds_rel_start  )
                
            if cds_rel_end < t_length:
                t_contents["bed_UTR_3"] = (cds_rel_end, t_length )

# %%
find_rel_utr_cds_positions(gtf_all)

# %% [markdown]
# Now we can see that they are in the dictionary:

# %%
list(gtf_all.items())[1000:1002]
# Out:
# [('ENSG00000162512',
#   {'ENST00000336798': {'exons': [(30876552, 30878740),
#      (30874297, 30874588),
#      (30869467, 30873377)],
#     'CDS': [(30876552, 30877247, 0),
#      (30874297, 30874588, 1),
#      (30873214, 30873377, 2)],
#     'strand': '-',
#     'start': 30869467,
#     'end': 30878740,
#     'gene_type': 'protein_coding',
#     'length': 6392,
#     'bed_CDS': (1493, 2645),
#     'bed_UTR_5': (0, 1493),
#     'bed_UTR_3': (2645, 6392)},
#    'ENST00000339394': {'exons': [(30908449, 30908761),
#      (30878623, 30878740),
#      (30876552, 30877165),
#      (30874297, 30874588),
#      (30873135, 30873377)],
#     'CDS': [(30908449, 30908586, 0),
#      (30878623, 30878740, 1),
#      (30876552, 30877165, 2),
#      (30874297, 30874588, 3),
#      (30873214, 30873377, 4)],
#     'strand': '-',
#     'start': 30873135,
#     'end': 30908761,
#     'gene_type': 'protein_coding',
#     'length': 1580,
#     'bed_CDS': (175, 1501),
#     'bed_UTR_5': (0, 175),
#     'bed_UTR_3': (1501, 1580)},
#    'ENST00000471567': {'exons': [(30881358, 30881429),
#      (30878623, 30878740),
#      (30876767, 30877165)],
#     'CDS': [],
#     'strand': '-',
#     'start': 30876767,
#     'end': 30881429,
#     'gene_type': 'protein_coding',
#     'length': 589},
#    'ENST00000487984': {'exons': [(30880602, 30880769),
#      (30879977, 30880014),
#      (30878929, 30879012),
#      (30878676, 30878740)],
#     'CDS': [],
#     'strand': '-',
#     'start': 30878676,
#     'end': 30880769,
#     'gene_type': 'protein_coding',
#     'length': 355}}),
#  ('ENSG00000266210',
#   {'ENST00000578099': {'exons': [(30918469, 30918735)],
#     'CDS': [],
#     'strand': '-',
#     'start': 30918469,
#     'end': 30918735,
#     'gene_type': 'misc_RNA',
#     'length': 267}})]

# %% [markdown]
# ## Selecting Longest Appris Transcripts

# %% [markdown]
# When going through Appris transcripts, we pick only the "PRINCIPAL*" ones.

# %%
def read_principal_appris_trascript_list(appris_file, gtf_contents):
    """
    Reads the appris isoform file into a dictionary
    
    We assume that the files is of the form:
    Gene NAme \t GENE_ID \t TRANSCRIOPT_ID \t APPRIS_CATEGORY
    # C1orf112	ENSG00000000460	ENST00000286031	CCDS1285	PRINCIPAL:1
    
    The output dictionary is of the form:
    appris_genes[gene_id][transcript_id] = {  "gene_name": gene_name, "category": category }
    """
    
    appris_genes = defaultdict(dict)
    myopen=open
    if appris_file.endswith(".gz"):
        myopen = gzip.open
    
    with myopen(appris_file, "rt") as input_stream:
        for entry in input_stream:
            contents = entry.strip().split()
            if len(contents) < 5:
                continue
            gene_name, gene_id, transcript_id, dummy, category = contents
            if not category.startswith("PRINCIPAL"):
                continue
            appris_genes[gene_id][transcript_id] = gtf_contents[gene_id][transcript_id]
            
    return appris_genes

# %%
appris_principal_transcripts = read_principal_appris_trascript_list(appris_file, gtf_all)
len(appris_principal_transcripts)
# Out:
# 20371

# %%
def pick_longest_appris_transcripts( appris_genes ):
    longest_picks = defaultdict(dict)
    
    for gene, transcripts in appris_genes.items():
        g_transcripts = list( transcripts.items() )
        longest_transcript = g_transcripts[0]
        for t_name, t_contents in g_transcripts[1:]:
            if t_contents["length"] > longest_transcript[1]["length"]:
                longest_transcript = (t_name, t_contents)
        longest_picks[ gene ][longest_transcript[0]] = longest_transcript[1]   
    return longest_picks

# %%
longest_appris_transcripts = pick_longest_appris_transcripts(appris_principal_transcripts)
len(longest_appris_transcripts)
# Out:
# 20371

# %% [markdown]
# How many of these transcripts do NOT have CDS?

# %%
no_cds_transcripts = defaultdict(dict)
for g, transcripts in longest_appris_transcripts.items():
    # There is only one (longest) transcript so pick that
    t_name, t_contents = list(transcripts.items())[0]
    CDS = t_contents.get("bed_CDS", None)
    if CDS == None:
        no_cds_transcripts[g][t_name] = t_contents
print(len(no_cds_transcripts))
# Out:
# 0

# %% [markdown]
# Great! So all appris transcripts have CDS region annotated!

# %% [markdown]
# Just for verification, let's look at GAPDH and BRCA2 and see if we picked the longest transcript:

# %%
for t_name, t_contents in appris_principal_transcripts["ENSG00000111640"].items():
    print(t_name, t_contents["length"])
print("--------")
for t_name, t_contents in appris_principal_transcripts["ENSG00000139618"].items():
    print(t_name, t_contents["length"])
# Out:
# ENST00000396859 1256
# ENST00000229239 1875
# ENST00000396861 1348
# --------
# ENST00000544455 10984
# ENST00000380152 11986

# %%
longest_appris_transcripts["ENSG00000111640"]
# Out:
# {'ENST00000229239': {'exons': [(6533927, 6534569),
#    (6534810, 6534861),
#    (6536494, 6536593),
#    (6536684, 6536790),
#    (6536920, 6537010),
#    (6537101, 6537216),
#    (6537309, 6537390),
#    (6537584, 6537996),
#    (6538101, 6538371)],
#   'CDS': [(6534833, 6534861, 1),
#    (6536494, 6536593, 2),
#    (6536684, 6536790, 3),
#    (6536920, 6537010, 4),
#    (6537101, 6537216, 5),
#    (6537309, 6537390, 6),
#    (6537584, 6537996, 7),
#    (6538101, 6538167, 8)],
#   'strand': '+',
#   'start': 6533927,
#   'end': 6538371,
#   'gene_type': 'protein_coding',
#   'length': 1875,
#   'bed_CDS': (666, 1671),
#   'bed_UTR_5': (0, 666),
#   'bed_UTR_3': (1671, 1875)}}

# %%
longest_appris_transcripts["ENSG00000139618"]
# Out:
# {'ENST00000380152': {'exons': [(32315474, 32315667),
#    (32316422, 32316527),
#    (32319077, 32319325),
#    (32325076, 32325184),
#    (32326101, 32326150),
#    (32326242, 32326282),
#    (32326499, 32326613),
#    (32329443, 32329492),
#    (32330919, 32331030),
#    (32332272, 32333387),
#    (32336265, 32341196),
#    (32344558, 32344653),
#    (32346827, 32346896),
#    (32354861, 32355288),
#    (32356428, 32356609),
#    (32357742, 32357929),
#    (32362523, 32362693),
#    (32363179, 32363533),
#    (32370402, 32370557),
#    (32370956, 32371100),
#    (32376670, 32376791),
#    (32379317, 32379515),
#    (32379750, 32379913),
#    (32380007, 32380145),
#    (32394689, 32394933),
#    (32396898, 32397044),
#    (32398162, 32400266)],
#   'CDS': [(32316461, 32316527, 1),
#    (32319077, 32319325, 2),
#    (32325076, 32325184, 3),
#    (32326101, 32326150, 4),
#    (32326242, 32326282, 5),
#    (32326499, 32326613, 6),
#    (32329443, 32329492, 7),
#    (32330919, 32331030, 8),
#    (32332272, 32333387, 9),
#    (32336265, 32341196, 10),
#    (32344558, 32344653, 11),
#    (32346827, 32346896, 12),
#    (32354861, 32355288, 13),
#    (32356428, 32356609, 14),
#    (32357742, 32357929, 15),
#    (32362523, 32362693, 16),
#    (32363179, 32363533, 17),
#    (32370402, 32370557, 18),
#    (32370956, 32371100, 19),
#    (32376670, 32376791, 20),
#    (32379317, 32379515, 21),
#    (32379750, 32379913, 22),
#    (32380007, 32380145, 23),
#    (32394689, 32394933, 24),
#    (32396898, 32397044, 25),
#    (32398162, 32398767, 26)],
#   'strand': '+',
#   'start': 32315474,
#   'end': 32400266,
#   'gene_type': 'protein_coding',
#   'length': 11986,
#   'bed_CDS': (233, 10487),
#   'bed_UTR_5': (0, 233),
#   'bed_UTR_3': (10487, 11986)}}

# %% [markdown]
# This gives us confidence that we picked the longest principal transcripts

# %% [markdown]
# ## Sanity Checks
#
# At this point, we have the relative coordinates of CDS and UTRs, and we picked the longest principal appris transcripts.
# Now, we can do some sanity checks to see if there are any issues with our implmentation.
#
# These sanity checks are:
#     1. The length of CDS should be divisible by 3
#     2. The start codon should be ATG. The stop codon should be one of TAG, TGA, TAA
#
# Also, it is claimed that the alternative isoforms for the principal Appris genes have identical CDS. We walso wan to confirm this.
#     3. CDS regions

# %% [markdown]
# ### 1. CDS Length

# %%
# The remainders are stored at the corresponding index position
# i.e., CDS_remainder_by_3[1] will hold the total number of remainders whose CDS length is of the form 3m + 1
CDS_remainder_by_3 = [0,0,0]
non_zero_remainder_transcripts = defaultdict(dict)

for g, transcripts in longest_appris_transcripts.items():
    for t_name, t_contents in transcripts.items():
        bed_CDS = t_contents.get("bed_CDS", None)
        this_remainder = (bed_CDS[1] - bed_CDS[0]) % 3
        CDS_remainder_by_3[this_remainder] += 1
        if this_remainder != 0:
            non_zero_remainder_transcripts[g][t_name] = t_contents

print("CDS length divisible by 3: ", CDS_remainder_by_3[0])
print("CDS length NOT divisible by 3: ", CDS_remainder_by_3[1] + CDS_remainder_by_3[2])
# Out:
# CDS length divisible by 3:  19959
# CDS length NOT divisible by 3:  412

# %% [markdown]
# Most of the transcripts have CDS multiple of 3. But some of them don't. Now we look at what kind of transcripts they are:

# %%
CDS_non_zero_remainder_plus_strand = 0
one_exon_non_zero_remainder_cases = list()
gene_types = defaultdict(int)

for g, transcripts in non_zero_remainder_transcripts.items():
     for t_name, t_contents in transcripts.items():
        gene_types[gtf_all[g][t_name]["gene_type"]] +=1  
        if t_contents["strand"] == "+":
            CDS_non_zero_remainder_plus_strand += 1
        if len(t_contents["CDS"]) == 1:
            one_exon_non_zero_remainder_cases.append( t_name)

all_total = 0
for g_type, g_count in gene_types.items():
    print(g_type, g_count)
    all_total += g_count
print(all_total)
# Out:
# polymorphic_pseudogene 16
# protein_coding 148
# IG_C_gene 7
# IG_J_gene 15
# IG_V_gene 67
# TR_J_gene 31
# TR_C_gene 6
# TR_V_gene 89
# IG_D_gene 31
# TR_D_gene 2
# 412

# %%
all_gene_types = defaultdict(int)
total_t = 0

for g, transcripts in appris_principal_transcripts.items():
    for t_name, t_contents in transcripts.items():
        all_gene_types[ t_contents["gene_type"] ] +=1
        total_t += 1
        
        
for  g_type, g_count in all_gene_types.items():
    print(g_type, g_count)
print(total_t)
# Out:
# protein_coding 26784
# polymorphic_pseudogene 42
# IG_C_gene 14
# IG_J_gene 18
# IG_V_gene 144
# TR_J_gene 79
# TR_C_gene 6
# TR_V_gene 106
# TR_D_gene 4
# IG_D_gene 37
# 27234

# %%
print(len(one_exon_non_zero_remainder_cases), "\n" ,  one_exon_non_zero_remainder_cases[:20])
# Out:
# 118
#  ['ENST00000641057', 'ENST00000504970', 'ENST00000377712', 'ENST00000390237', 'ENST00000390238', 'ENST00000390239', 'ENST00000390240', 'ENST00000390242', 'ENST00000620613', 'ENST00000429239', 'ENST00000394191', 'ENST00000506619', 'ENST00000514827', 'ENST00000587816', 'ENST00000439431', 'ENST00000390333', 'ENST00000390337', 'ENST00000390338', 'ENST00000390341', 'ENST00000390412']

# %% [markdown]
# A closer look at the transcript ENST00000426406 directly on the file: gencode.v29.annotation.gtf.gz

# %%
! zcat ../annotation/gencode.v29.annotation.gtf.gz | grep ENST00000377712
# Out:
# gzip: ../annotation/gencode.v29.annotation.gtf.gz: No such file or directory

# %% [markdown]
# This pseodogene looks problematic in the reference!

# %%
longest_appris_transcripts["ENSG00000204872"]["ENST00000377712"]
# Out:
# {'exons': [(73700576, 73701340)],
#  'CDS': [(73700627, 73701305, 0)],
#  'strand': '-',
#  'start': 73700576,
#  'end': 73701340,
#  'gene_type': 'polymorphic_pseudogene',
#  'length': 765,
#  'bed_CDS': (35, 714),
#  'bed_UTR_5': (0, 35),
#  'bed_UTR_3': (714, 765)}

# %%
73701305 - 73700627 +1
# Out:
# 679

# %%
714 - 35
# Out:
# 679

# %% [markdown]
# Both our calculations and eye-inspection of the GTF file tell us that CDS length of this gene is 679 and is not divisible by 3

# %% [markdown]
# ### 2. Start & Stop Codons

# %%
t_fasta_stream = FastaFile(transcripts_fasta)

clipped = list()
start_triplets = defaultdict(int)
stop_triplets = defaultdict(int)

for this_fasta_entry in t_fasta_stream:
    contents = this_fasta_entry.header.strip().split("|")
    this_t = contents[0].split(".")[0]
    
    g_contents = contents[1].split(".")
    this_g = g_contents[0]
    if len(g_contents) >= 2 and "PAR_Y" in g_contents[1]:
        continue
    
    transcripts = longest_appris_transcripts.get(this_g, None)
    if bed_CDS == None:
        continue
    if this_t in list(longest_appris_transcripts[this_g].keys()):
        bed_CDS = longest_appris_transcripts[this_g][this_t].get("bed_CDS", None)
        
        if bed_CDS != None:
            start_codon_coord = bed_CDS[0]
            start_triplets[ this_fasta_entry.sequence[ start_codon_coord:start_codon_coord+3 ]  ] += 1
            stop_triplets[ this_fasta_entry.sequence[ bed_CDS[1]:bed_CDS[1] + 3 ]  ] += 1

print(start_triplets)
print("---------------------------")
print(stop_triplets)
# Out:
# defaultdict(<class 'int'>, {'ATG': 19995, 'GTG': 17, 'AGG': 8, 'AAG': 9, 'GCT': 7, 'GAA': 11, 'TGA': 23, 'CTG': 23, 'GGT': 10, 'GGG': 15, 'CTC': 10, 'GGA': 12, 'CTT': 6, 'AGT': 3, 'GAT': 10, 'ATT': 9, 'TGT': 3, 'GAC': 3, 'GAG': 6, 'GCG': 6, 'CAG': 7, 'AGC': 8, 'CCT': 7, 'TTC': 3, 'GCC': 8, 'ACT': 8, 'TTG': 4, 'ATC': 4, 'ATA': 11, 'TCC': 7, 'AAC': 4, 'CAC': 3, 'ACG': 2, 'TAA': 6, 'AGA': 9, 'CTA': 4, 'CAA': 6, 'TAG': 1, 'CGA': 1, 'ACC': 2, 'GTA': 11, 'TCT': 3, 'TTA': 3, 'CGC': 4, 'CGG': 1, 'TAT': 3, 'GCA': 3, 'TTT': 3, 'GTC': 5, 'AAA': 2, 'ACA': 5, 'CCA': 4, 'TGG': 7, 'TCA': 6, 'CAT': 1, 'TAC': 5, 'GTT': 3, 'CCG': 3, 'TGC': 2, 'GGC': 2, 'CGT': 1, 'CCC': 2, 'AAT': 1})
# ---------------------------
# defaultdict(<class 'int'>, {'TAG': 4433, 'TAA': 5640, 'TGA': 9798, '': 493, 'ACA': 1, 'TAT': 1, 'GTG': 1, 'ATA': 1, 'TGG': 1, 'GAC': 1, 'TTG': 1})

# %%
lenght_dict = defaultdict(int)
short_and_p_coding = defaultdict(dict)
for g, transcripts in longest_appris_transcripts.items():
    for t_name , t_contents in transcripts.items():
        cds_length = t_contents["bed_CDS"][1] - t_contents["bed_CDS"][0]
        lenght_dict[ cds_length ] += 1
        if cds_length < 150 and t_contents["gene_type"] == "protein_coding":
            short_and_p_coding[g][t_name] = t_contents
            
print("There are", len(short_and_p_coding), "many short and protein coding transcripts (CDS length < 150)")
# Out:
# There are 77 many short and protein coding transcripts (CDS length < 150)

# %% [markdown]
# We think that these few short transcripts will not impact our results significantly. Also, very few reads are going to map to them.

# %% [markdown]
# ### Selecting Only Protein-Coding Genes
#
# Our sanity checks above suggest that many (though not all) of the transcripts that are failing CDS length and start / stop codon checks are not non-protein coding genes. So we decided to pick only protein-coding genes.

# %%
protein_coding_longest_transcripts = defaultdict(dict)
for g, transcripts in longest_appris_transcripts.items():
    for t_name , t_contents in transcripts.items():
        if t_contents["gene_type"] == "protein_coding":
            protein_coding_longest_transcripts[g][t_name] = t_contents
long_p_coding_count = len(protein_coding_longest_transcripts)
print("There are {} protein coding transcripts picked".format(long_p_coding_count))
# Out:
# There are 19922 protein coding transcripts picked

# %% [markdown]
# Now we revisit our sanity checks using the protein coding transcripts only
#
# ### 1. CDS Length (Revisited)

# %%
CDS_remainder_by_3 = [0,0,0]
non_zero_remainder_transcripts = defaultdict(dict)

for g, transcripts in protein_coding_longest_transcripts.items():
    for t_name, t_contents in transcripts.items():
        bed_CDS = t_contents.get("bed_CDS", None)
        this_remainder = (bed_CDS[1] - bed_CDS[0]) % 3
        CDS_remainder_by_3[this_remainder] += 1
        if this_remainder != 0:
            non_zero_remainder_transcripts[g][t_name] = t_contents

print("CDS length divisible by 3: ", CDS_remainder_by_3[0])
print("CDS length NOT divisible by 3: ", CDS_remainder_by_3[1] + CDS_remainder_by_3[2])
# Out:
# CDS length divisible by 3:  19774
# CDS length NOT divisible by 3:  148

# %% [markdown]
# ### 2. Start & Stop Codons (Revisited)

# %%
t_fasta_stream = FastaFile(transcripts_fasta)

clipped = list()
start_triplets = defaultdict(int)
stop_triplets = defaultdict(int)
empty_stop_triplets = defaultdict(dict)
transcripts_with_stop_codon = defaultdict(dict)

for this_fasta_entry in t_fasta_stream:
    contents = this_fasta_entry.header.strip().split("|")
    this_t = contents[0].split(".")[0]
    
    g_contents = contents[1].split(".")
    this_g = g_contents[0]
    if len(g_contents) >= 2 and "PAR_Y" in g_contents[1]:
        continue
    
    transcripts = protein_coding_longest_transcripts.get(this_g, None)

    if this_t in list(protein_coding_longest_transcripts[this_g].keys()):
        bed_CDS = protein_coding_longest_transcripts[this_g][this_t].get("bed_CDS", None)
        
        if bed_CDS != None:
            start_codon_coord = bed_CDS[0]
            start_triplets[ this_fasta_entry.sequence[ start_codon_coord:start_codon_coord+3 ]  ] += 1
            observed_stop_triplet = this_fasta_entry.sequence[ bed_CDS[1]:bed_CDS[1] + 3 ]
            stop_triplets[ observed_stop_triplet ] += 1
            if observed_stop_triplet == '':
                empty_stop_triplets[this_g][this_t] = protein_coding_longest_transcripts[this_g][this_t]
            else:
                transcripts_with_stop_codon[this_g][this_t] = protein_coding_longest_transcripts[this_g][this_t]

print("start_triplets")                
print(start_triplets)
print("---------------------------")
print("stop_triplets")  
print(stop_triplets)
print("---------------------------")
print("Number of transcripts_with_stop_codon = ", len(transcripts_with_stop_codon) )
# Out:
# start_triplets
# defaultdict(<class 'int'>, {'ATG': 19713, 'GTG': 11, 'AGG': 3, 'AAG': 9, 'GCT': 4, 'GAA': 4, 'TGA': 4, 'CTG': 22, 'GGT': 1, 'GGG': 7, 'CTC': 3, 'GGA': 6, 'CTT': 3, 'AGT': 3, 'GCG': 6, 'CAG': 5, 'AGC': 5, 'CCT': 6, 'TTC': 3, 'GCC': 5, 'ACT': 6, 'GAG': 2, 'TTG': 4, 'ATC': 4, 'ATA': 4, 'ATT': 7, 'TCC': 7, 'AAC': 3, 'CAC': 2, 'ACG': 2, 'TAA': 1, 'AGA': 5, 'GTA': 1, 'TCT': 2, 'CTA': 1, 'TTA': 2, 'ACC': 1, 'CGC': 4, 'CAA': 5, 'CGG': 1, 'TAT': 2, 'GAT': 4, 'GCA': 1, 'TTT': 1, 'GTC': 1, 'AAA': 1, 'GTT': 2, 'TCA': 4, 'TGG': 3, 'CCA': 3, 'GGC': 2, 'ACA': 3, 'CCG': 2, 'GAC': 1, 'TAC': 1, 'CGT': 1, 'TGC': 1, 'CCC': 1, 'AAT': 1})
# ---------------------------
# stop_triplets
# defaultdict(<class 'int'>, {'TAG': 4415, 'TAA': 5625, 'TGA': 9782, '': 100})
# ---------------------------
# Number of transcripts_with_stop_codon =  19822

# %% [markdown]
# Clearly, picking only protein coding genes largely improved our results!
#
# The empty triplets are coming from transcripts without 3UTR.
#
# We can clearly see this from the GTF annotation or from our dictionary:

# %%
empty_stop_triplets
# Out:
# defaultdict(dict,
#             {'ENSG00000204060': {'ENST00000641094': {'exons': [(41361931,
#                  41362344),
#                 (41381616, 41382200),
#                 (41382202, 41382678)],
#                'CDS': [(41361931, 41362344, 0),
#                 (41381616, 41382200, 1),
#                 (41382202, 41382678, 2)],
#                'strand': '+',
#                'start': 41361931,
#                'end': 41382678,
#                'gene_type': 'protein_coding',
#                'length': 1476,
#                'bed_CDS': (0, 1476)}},
#              'ENSG00000274068': {'ENST00000357393': {'exons': [(108963361,
#                  108963484),
#                 (108849537, 108849576),
#                 (108848912, 108849060),
#                 (108848752, 108848814),
#                 (108843134, 108843267),
#                 (108837660, 108837706)],
#                'CDS': [(108963361, 108963474, 0),
#                 (108849537, 108849576, 1),
#                 (108848912, 108849060, 2),
#                 (108848752, 108848814, 3),
#                 (108843134, 108843267, 4),
#                 (108837660, 108837706, 5)],
#                'strand': '-',
#                'start': 108837660,
#                'end': 108963484,
#                'gene_type': 'protein_coding',
#                'length': 557,
#                'bed_CDS': (10, 557),
#                'bed_UTR_5': (0, 10)}},
#              'ENSG00000271810': {'ENST00000606505': {'exons': [(112711266,
#                  112711355),
#                 (112711008, 112711071),
#                 (112710744, 112710851),
#                 (112710460, 112710611),
#                 (112705100, 112705168),
#                 (112703644, 112703806),
#                 (112702999, 112703119),
#                 (112702648, 112702693)],
#                'CDS': [(112711266, 112711355, 0),
#                 (112711008, 112711071, 1),
#                 (112710744, 112710851, 2),
#                 (112710460, 112710611, 3),
#                 (112705100, 112705168, 4),
#                 (112703644, 112703806, 5),
#                 (112702999, 112703119, 6),
#                 (112702648, 112702693, 7)],
#                'strand': '-',
#                'start': 112702648,
#                'end': 112711355,
#                'gene_type': 'protein_coding',
#                'length': 813,
#                'bed_CDS': (0, 813)}},
#              'ENSG00000280778': {'ENST00000625258': {'exons': [(145927258,
#                  145927289),
#                 (145977084, 145977152),
#                 (145977483, 145977539),
#                 (145977778, 145977811)],
#                'CDS': [(145977113, 145977152, 1),
#                 (145977483, 145977539, 2),
#                 (145977778, 145977811, 3)],
#                'strand': '+',
#                'start': 145927258,
#                'end': 145977811,
#                'gene_type': 'protein_coding',
#                'length': 192,
#                'bed_CDS': (61, 192),
#                'bed_UTR_5': (0, 61)}},
#              'ENSG00000254706': {'ENST00000431696': {'exons': [(162365407,
#                  162365569),
#                 (162367052, 162367204),
#                 (162381891, 162382115)],
#                'CDS': [(162365497, 162365569, 0),
#                 (162367052, 162367204, 1),
#                 (162381891, 162382115, 2)],
#                'strand': '+',
#                'start': 162365407,
#                'end': 162382115,
#                'gene_type': 'protein_coding',
#                'length': 541,
#                'bed_CDS': (90, 541),
#                'bed_UTR_5': (0, 90)}},
#              'ENSG00000283952': {'ENST00000638880': {'exons': [(211188497,
#                  211188533),
#                 (211183058, 211183101),
#                 (211182157, 211182224),
#                 (211107254, 211107377),
#                 (211103496, 211103602),
#                 (211090562, 211090690),
#                 (211082872, 211082898)],
#                'CDS': [(211107254, 211107276, 3),
#                 (211103496, 211103602, 4),
#                 (211090562, 211090690, 5),
#                 (211082872, 211082898, 6)],
#                'strand': '-',
#                'start': 211082872,
#                'end': 211188533,
#                'gene_type': 'protein_coding',
#                'length': 536,
#                'bed_CDS': (250, 536),
#                'bed_UTR_5': (0, 250)}},
#              'ENSG00000284701': {'ENST00000434431': {'exons': [(46479565,
#                  46479702),
#                 (46480405, 46480764),
#                 (46484244, 46484425)],
#                'CDS': [(46479586, 46479702, 0),
#                 (46480405, 46480764, 1),
#                 (46484244, 46484425, 2)],
#                'strand': '+',
#                'start': 46479565,
#                'end': 46484425,
#                'gene_type': 'protein_coding',
#                'length': 680,
#                'bed_CDS': (21, 680),
#                'bed_UTR_5': (0, 21)}},
#              'ENSG00000114786': {'ENST00000637978': {'exons': [(51977884,
#                  51978082),
#                 (51978259, 51978374),
#                 (51980393, 51980628),
#                 (51984047, 51984158),
#                 (51985207, 51985271),
#                 (51985361, 51985465),
#                 (51985852, 51985946),
#                 (51986255, 51986331),
#                 (51986415, 51986504),
#                 (51986605, 51986661),
#                 (51986988, 51987061),
#                 (51987147, 51987196),
#                 (51987309, 51987453),
#                 (51987556, 51987624),
#                 (51988524, 51988603),
#                 (51988766, 51988826),
#                 (51988911, 51989037)],
#                'CDS': [(51977884, 51978082, 0),
#                 (51978259, 51978374, 1),
#                 (51980393, 51980628, 2),
#                 (51984047, 51984158, 3),
#                 (51985207, 51985271, 4),
#                 (51985361, 51985465, 5),
#                 (51985852, 51985946, 6),
#                 (51986255, 51986331, 7),
#                 (51986415, 51986504, 8),
#                 (51986605, 51986661, 9),
#                 (51986988, 51987061, 10),
#                 (51987147, 51987196, 11),
#                 (51987309, 51987453, 12),
#                 (51987556, 51987624, 13),
#                 (51988524, 51988603, 14),
#                 (51988766, 51988826, 15),
#                 (51988911, 51989037, 16)],
#                'strand': '+',
#                'start': 51977884,
#                'end': 51989037,
#                'gene_type': 'protein_coding',
#                'length': 1758,
#                'bed_CDS': (0, 1758)}},
#              'ENSG00000251012': {'ENST00000490594': {'exons': [(119147375,
#                  119147587),
#                 (119187775, 119187807)],
#                'CDS': [(119147375, 119147587, 0), (119187775, 119187807, 1)],
#                'strand': '+',
#                'start': 119147375,
#                'end': 119187807,
#                'gene_type': 'protein_coding',
#                'length': 246,
#                'bed_CDS': (0, 246)}},
#              'ENSG00000274810': {'ENST00000632629': {'exons': [(132684554,
#                  132684770),
#                 (132683399, 132683524),
#                 (132682703, 132682818),
#                 (132681914, 132682090),
#                 (132644838, 132644896)],
#                'CDS': [(132684554, 132684770, 0),
#                 (132683399, 132683524, 1),
#                 (132682703, 132682818, 2),
#                 (132681914, 132682090, 3),
#                 (132644838, 132644896, 4)],
#                'strand': '-',
#                'start': 132644838,
#                'end': 132684770,
#                'gene_type': 'protein_coding',
#                'length': 695,
#                'bed_CDS': (0, 695)}},
#              'ENSG00000283149': {'ENST00000418776': {'exons': [(186581995,
#                  186582077),
#                 (186582716, 186582773),
#                 (186583865, 186583976),
#                 (186584430, 186584589),
#                 (186585344, 186585381),
#                 (186597054, 186597103)],
#                'CDS': [(186581995, 186582077, 0),
#                 (186582716, 186582773, 1),
#                 (186583865, 186583976, 2),
#                 (186584430, 186584589, 3),
#                 (186585344, 186585381, 4),
#                 (186597054, 186597103, 5)],
#                'strand': '+',
#                'start': 186581995,
#                'end': 186597103,
#                'gene_type': 'protein_coding',
#                'length': 501,
#                'bed_CDS': (0, 501)}},
#              'ENSG00000250913': {'ENST00000506619': {'exons': [(9272364,
#                  9272914)],
#                'CDS': [(9272364, 9272914, 0)],
#                'strand': '+',
#                'start': 9272364,
#                'end': 9272914,
#                'gene_type': 'protein_coding',
#                'length': 551,
#                'bed_CDS': (0, 551)}},
#              'ENSG00000285385': {'ENST00000513325': {'exons': [(88523810,
#                  88523932),
#                 (88595557, 88595614),
#                 (88597950, 88598087),
#                 (88605795, 88606049),
#                 (88649840, 88649847)],
#                'CDS': [(88605824, 88606049, 3), (88649840, 88649847, 4)],
#                'strand': '+',
#                'start': 88523810,
#                'end': 88649847,
#                'gene_type': 'protein_coding',
#                'length': 582,
#                'bed_CDS': (348, 582),
#                'bed_UTR_5': (0, 348)}},
#              'ENSG00000272772': {'ENST00000519718': {'exons': [(134225760,
#                  134226071),
#                 (134173926, 134174022),
#                 (134167170, 134167243)],
#                'CDS': [(134225760, 134225861, 0),
#                 (134173926, 134174022, 1),
#                 (134167170, 134167243, 2)],
#                'strand': '-',
#                'start': 134167170,
#                'end': 134226071,
#                'gene_type': 'protein_coding',
#                'length': 483,
#                'bed_CDS': (210, 483),
#                'bed_UTR_5': (0, 210)}},
#              'ENSG00000285085': {'ENST00000428778': {'exons': [(32154238,
#                  32154373),
#                 (32153737, 32153836),
#                 (32152095, 32152175),
#                 (32151809, 32151899),
#                 (32150495, 32150583)],
#                'CDS': [(32152095, 32152102, 2),
#                 (32151809, 32151899, 3),
#                 (32150495, 32150583, 4)],
#                'strand': '-',
#                'start': 32150495,
#                'end': 32154373,
#                'gene_type': 'protein_coding',
#                'length': 497,
#                'bed_CDS': (309, 497),
#                'bed_UTR_5': (0, 309)}},
#              'ENSG00000250264': {'ENST00000452392': {'exons': [(32838653,
#                  32838822),
#                 (32837741, 32838237),
#                 (32837537, 32837651),
#                 (32835643, 32835773),
#                 (32835154, 32835359),
#                 (32832627, 32832824),
#                 (32832333, 32832461),
#                 (32830618, 32830806),
#                 (32830267, 32830440),
#                 (32829930, 32830089),
#                 (32829400, 32829536),
#                 (32816861, 32816952),
#                 (32815044, 32815201),
#                 (32814320, 32814601),
#                 (32813767, 32813833)],
#                'CDS': [(32837741, 32838233, 1),
#                 (32837537, 32837651, 2),
#                 (32835643, 32835773, 3),
#                 (32835154, 32835359, 4),
#                 (32832627, 32832824, 5),
#                 (32832333, 32832461, 6),
#                 (32830618, 32830806, 7),
#                 (32830267, 32830440, 8),
#                 (32829930, 32830089, 9),
#                 (32829400, 32829536, 10),
#                 (32816861, 32816952, 11),
#                 (32815044, 32815201, 12),
#                 (32814320, 32814601, 13),
#                 (32813767, 32813833, 14)],
#                'strand': '-',
#                'start': 32813767,
#                'end': 32838822,
#                'gene_type': 'protein_coding',
#                'length': 2705,
#                'bed_CDS': (174, 2705),
#                'bed_UTR_5': (0, 174)}},
#              'ENSG00000248993': {'ENST00000429234': {'exons': [(32952949,
#                  32953122),
#                 (32940753, 32940815),
#                 (32938684, 32938965),
#                 (32937364, 32937456)],
#                'CDS': [(32952949, 32953036, 0),
#                 (32940753, 32940815, 1),
#                 (32938684, 32938965, 2),
#                 (32937364, 32937456, 3)],
#                'strand': '-',
#                'start': 32937364,
#                'end': 32953122,
#                'gene_type': 'protein_coding',
#                'length': 612,
#                'bed_CDS': (86, 612),
#                'bed_UTR_5': (0, 86)}},
#              'ENSG00000118412': {'ENST00000551025': {'exons': [(89829900,
#                  89830106),
#                 (89846562, 89846644),
#                 (89853166, 89853234),
#                 (89854817, 89854917),
#                 (89855470, 89855544),
#                 (89857084, 89857199),
#                 (89862126, 89864371),
#                 (89865953, 89869082),
#                 (89871289, 89871412)],
#                'CDS': [(89846590, 89846644, 1),
#                 (89853166, 89853234, 2),
#                 (89854817, 89854917, 3),
#                 (89855470, 89855544, 4),
#                 (89857084, 89857199, 5),
#                 (89862126, 89864371, 6),
#                 (89865953, 89869082, 7),
#                 (89871289, 89871412, 8)],
#                'strand': '+',
#                'start': 89829900,
#                'end': 89871412,
#                'gene_type': 'protein_coding',
#                'length': 6151,
#                'bed_CDS': (235, 6151),
#                'bed_UTR_5': (0, 235)}},
#              'ENSG00000281613': {'ENST00000587816': {'exons': [(112236806,
#                  112236916),
#                 (112345113, 112345159),
#                 (112347292, 112347407),
#                 (112349193, 112349321),
#                 (112349604, 112350094)],
#                'CDS': [(112349709, 112350094, 4)],
#                'strand': '+',
#                'start': 112236806,
#                'end': 112350094,
#                'gene_type': 'protein_coding',
#                'length': 894,
#                'bed_CDS': (508, 894),
#                'bed_UTR_5': (0, 508)}},
#              'ENSG00000282218': {'ENST00000467125': {'exons': [(117573467,
#                  117573571),
#                 (117570860, 117570955),
#                 (117569572, 117569736),
#                 (117566854, 117567034),
#                 (117321217, 117321394),
#                 (117319868, 117320030),
#                 (117318211, 117318252)],
#                'CDS': [(117573467, 117573571, 0),
#                 (117570860, 117570955, 1),
#                 (117569572, 117569736, 2),
#                 (117566854, 117567034, 3),
#                 (117321217, 117321394, 4),
#                 (117319868, 117320030, 5),
#                 (117318211, 117318252, 6)],
#                'strand': '-',
#                'start': 117318211,
#                'end': 117573571,
#                'gene_type': 'protein_coding',
#                'length': 930,
#                'bed_CDS': (0, 930)}},
#              'ENSG00000249319': {'ENST00000450043': {'exons': [(66087761,
#                  66087791),
#                 (66088807, 66088921),
#                 (66089091, 66089175),
#                 (66089276, 66089335),
#                 (66089612, 66089695),
#                 (66092006, 66092086),
#                 (66092557, 66092663),
#                 (66127704, 66127740),
#                 (66130744, 66130842),
#                 (66134280, 66134374),
#                 (66145443, 66145500),
#                 (66152208, 66152277)],
#                'CDS': [(66087761, 66087791, 0),
#                 (66088807, 66088921, 1),
#                 (66089091, 66089175, 2),
#                 (66089276, 66089335, 3),
#                 (66089612, 66089695, 4),
#                 (66092006, 66092086, 5),
#                 (66092557, 66092663, 6),
#                 (66127704, 66127740, 7),
#                 (66130744, 66130842, 8),
#                 (66134280, 66134374, 9),
#                 (66145443, 66145500, 10),
#                 (66152208, 66152277, 11)],
#                'strand': '+',
#                'start': 66087761,
#                'end': 66152277,
#                'gene_type': 'protein_coding',
#                'length': 922,
#                'bed_CDS': (0, 922)}},
#              'ENSG00000285772': {'ENST00000435873': {'exons': [(92142463,
#                  92142952),
#                 (92131807, 92131872)],
#                'CDS': [(92142463, 92142486, 0), (92131807, 92131872, 1)],
#                'strand': '-',
#                'start': 92131807,
#                'end': 92142952,
#                'gene_type': 'protein_coding',
#                'length': 556,
#                'bed_CDS': (466, 556),
#                'bed_UTR_5': (0, 466)}},
#              'ENSG00000285953': {'ENST00000650585': {'exons': [(92245790,
#                  92245924),
#                 (92244902, 92245134),
#                 (92244002, 92244149),
#                 (92242034, 92242137),
#                 (92240993, 92241152),
#                 (92237667, 92237759),
#                 (92236413, 92236542),
#                 (92235403, 92235646),
#                 (92234808, 92234923),
#                 (92234449, 92234592),
#                 (92226526, 92226682),
#                 (92225720, 92225827),
#                 (92222822, 92222978),
#                 (92221902, 92222053),
#                 (92214611, 92214777),
#                 (92213892, 92213979),
#                 (92213195, 92213401),
#                 (92131774, 92131872)],
#                'CDS': [(92242034, 92242135, 3),
#                 (92240993, 92241152, 4),
#                 (92237667, 92237759, 5),
#                 (92236413, 92236542, 6),
#                 (92235403, 92235646, 7),
#                 (92234808, 92234923, 8),
#                 (92234449, 92234592, 9),
#                 (92226526, 92226682, 10),
#                 (92225720, 92225827, 11),
#                 (92222822, 92222978, 12),
#                 (92221902, 92222053, 13),
#                 (92214611, 92214777, 14),
#                 (92213892, 92213979, 15),
#                 (92213195, 92213401, 16),
#                 (92131774, 92131872, 17)],
#                'strand': '-',
#                'start': 92131774,
#                'end': 92245924,
#                'gene_type': 'protein_coding',
#                'length': 2642,
#                'bed_CDS': (518, 2642),
#                'bed_UTR_5': (0, 518)}},
#              'ENSG00000270249': {'ENST00000514917': {'exons': [(102592285,
#                  102592444),
#                 (102587635, 102587770),
#                 (102584218, 102584338),
#                 (102569835, 102569924),
#                 (102566997, 102567083),
#                 (102566582, 102566736),
#                 (102541501, 102541662)],
#                'CDS': [(102592285, 102592362, 0),
#                 (102587635, 102587770, 1),
#                 (102584218, 102584338, 2),
#                 (102569835, 102569924, 3),
#                 (102566997, 102567083, 4),
#                 (102566582, 102566736, 5),
#                 (102541501, 102541662, 6)],
#                'strand': '-',
#                'start': 102541501,
#                'end': 102592444,
#                'gene_type': 'protein_coding',
#                'length': 911,
#                'bed_CDS': (82, 911),
#                'bed_UTR_5': (0, 82)}},
#              'ENSG00000284041': {'ENST00000478789': {'exons': [(150368790,
#                  150368941),
#                 (150388422, 150388501),
#                 (150396513, 150396915)],
#                'CDS': [(150388471, 150388501, 1), (150396513, 150396915, 2)],
#                'strand': '+',
#                'start': 150368790,
#                'end': 150396915,
#                'gene_type': 'protein_coding',
#                'length': 635,
#                'bed_CDS': (201, 635),
#                'bed_UTR_5': (0, 201)}},
#              'ENSG00000284956': {'ENST00000520607': {'exons': [(23084403,
#                  23084545),
#                 (23090148, 23090288),
#                 (23100637, 23100684),
#                 (23111720, 23111825),
#                 (23114657, 23114770),
#                 (23115508, 23115536)],
#                'CDS': [(23114732, 23114770, 4), (23115508, 23115536, 5)],
#                'strand': '+',
#                'start': 23084403,
#                'end': 23115536,
#                'gene_type': 'protein_coding',
#                'length': 581,
#                'bed_CDS': (513, 581),
#                'bed_UTR_5': (0, 513)}},
#              'ENSG00000285655': {'ENST00000523113': {'exons': [(66430185,
#                  66430378),
#                 (66442798, 66442844),
#                 (66444367, 66444420),
#                 (66444594, 66444748),
#                 (66445218, 66445324)],
#                'CDS': [(66444418, 66444420, 2),
#                 (66444594, 66444748, 3),
#                 (66445218, 66445324, 4)],
#                'strand': '+',
#                'start': 66430185,
#                'end': 66445324,
#                'gene_type': 'protein_coding',
#                'length': 557,
#                'bed_CDS': (292, 557),
#                'bed_UTR_5': (0, 292)}},
#              'ENSG00000258728': {'ENST00000556278': {'exons': [(34646645,
#                  34646786),
#                 (34647089, 34647258),
#                 (34648115, 34648171),
#                 (34648334, 34648456),
#                 (34655218, 34655317),
#                 (34655605, 34655665),
#                 (34656739, 34656908),
#                 (34657035, 34657113)],
#                'CDS': [(34646705, 34646786, 0),
#                 (34647089, 34647258, 1),
#                 (34648115, 34648171, 2),
#                 (34648334, 34648456, 3),
#                 (34655218, 34655317, 4),
#                 (34655605, 34655665, 5),
#                 (34656739, 34656908, 6),
#                 (34657035, 34657113, 7)],
#                'strand': '+',
#                'start': 34646645,
#                'end': 34657113,
#                'gene_type': 'protein_coding',
#                'length': 902,
#                'bed_CDS': (60, 902),
#                'bed_UTR_5': (0, 60)}},
#              'ENSG00000283378': {'ENST00000636699': {'exons': [(61330717,
#                  61331052),
#                 (61352014, 61352124),
#                 (61379875, 61380068),
#                 (61425702, 61425849),
#                 (61440605, 61440808),
#                 (61441463, 61441647),
#                 (61442873, 61443016),
#                 (61447338, 61447599),
#                 (61452887, 61453030)],
#                'CDS': [(61330968, 61331052, 0),
#                 (61352014, 61352124, 1),
#                 (61379875, 61380068, 2),
#                 (61425702, 61425849, 3),
#                 (61440605, 61440808, 4),
#                 (61441463, 61441647, 5),
#                 (61442873, 61443016, 6),
#                 (61447338, 61447599, 7),
#                 (61452887, 61453030, 8)],
#                'strand': '+',
#                'start': 61330717,
#                'end': 61453030,
#                'gene_type': 'protein_coding',
#                'length': 1728,
#                'bed_CDS': (251, 1728),
#                'bed_UTR_5': (0, 251)}},
#              'ENSG00000173077': {'ENST00000614246': {'exons': [(115400346,
#                  115400432),
#                 (115401193, 115401315)],
#                'CDS': [(115400346, 115400432, 0), (115401193, 115401315, 1)],
#                'strand': '+',
#                'start': 115400346,
#                'end': 115401315,
#                'gene_type': 'protein_coding',
#                'length': 210,
#                'bed_CDS': (0, 210)}},
#              'ENSG00000251184': {'ENST00000482796': {'exons': [(128941478,
#                  128941571),
#                 (128949189, 128949243),
#                 (128952773, 128952846),
#                 (128956350, 128956434),
#                 (128956952, 128957021)],
#                'CDS': [(128941534, 128941571, 0),
#                 (128949189, 128949243, 1),
#                 (128952773, 128952846, 2),
#                 (128956350, 128956434, 3),
#                 (128956952, 128957021, 4)],
#                'strand': '+',
#                'start': 128941478,
#                'end': 128957021,
#                'gene_type': 'protein_coding',
#                'length': 378,
#                'bed_CDS': (56, 378),
#                'bed_UTR_5': (0, 56)}},
#              'ENSG00000243660': {'ENST00000315429': {'exons': [(43436841,
#                  43436935),
#                 (43475721, 43475847),
#                 (43476107, 43476202),
#                 (43481429, 43481678)],
#                'CDS': [(43436841, 43436935, 0),
#                 (43475721, 43475847, 1),
#                 (43476107, 43476202, 2),
#                 (43481429, 43481678, 3)],
#                'strand': '+',
#                'start': 43436841,
#                'end': 43481678,
#                'gene_type': 'protein_coding',
#                'length': 568,
#                'bed_CDS': (0, 568)}},
#              'ENSG00000198788': {'ENST00000616479': {'exons': [(1102455,
#                  1102664),
#                 (1103274, 1103456)],
#                'CDS': [(1102455, 1102664, 0), (1103274, 1103456, 1)],
#                'strand': '+',
#                'start': 1102455,
#                'end': 1103456,
#                'gene_type': 'protein_coding',
#                'length': 393,
#                'bed_CDS': (0, 393)}},
#              'ENSG00000110321': {'ENST00000532082': {'exons': [(10808174,
#                  10808309),
#                 (10807255, 10807381),
#                 (10806820, 10806885),
#                 (10805907, 10806047),
#                 (10804913, 10805015),
#                 (10804287, 10804418),
#                 (10804137, 10804203),
#                 (10803899, 10804050),
#                 (10803480, 10803590),
#                 (10803261, 10803294)],
#                'CDS': [(10807255, 10807295, 1),
#                 (10806820, 10806885, 2),
#                 (10805907, 10806047, 3),
#                 (10804913, 10805015, 4),
#                 (10804287, 10804418, 5),
#                 (10804137, 10804203, 6),
#                 (10803899, 10804050, 7),
#                 (10803480, 10803590, 8),
#                 (10803261, 10803294, 9)],
#                'strand': '-',
#                'start': 10803261,
#                'end': 10808309,
#                'gene_type': 'protein_coding',
#                'length': 1069,
#                'bed_CDS': (222, 1069),
#                'bed_UTR_5': (0, 222)}},
#              'ENSG00000254979': {'ENST00000529411': {'exons': [(57409935,
#                  57410113),
#                 (57409175, 57409298),
#                 (57389887, 57389956),
#                 (57389010, 57389317)],
#                'CDS': [(57409935, 57410113, 0),
#                 (57409175, 57409298, 1),
#                 (57389887, 57389956, 2),
#                 (57389010, 57389317, 3)],
#                'strand': '-',
#                'start': 57389010,
#                'end': 57410113,
#                'gene_type': 'protein_coding',
#                'length': 681,
#                'bed_CDS': (0, 681)}},
#              'ENSG00000256591': {'ENST00000541135': {'exons': [(61430056,
#                  61430182),
#                 (61437625, 61437848),
#                 (61438004, 61438120),
#                 (61468664, 61468714),
#                 (61481782, 61481842)],
#                'CDS': [(61430147, 61430182, 0),
#                 (61437625, 61437848, 1),
#                 (61438004, 61438120, 2),
#                 (61468664, 61468714, 3),
#                 (61481782, 61481842, 4)],
#                'strand': '+',
#                'start': 61430056,
#                'end': 61481842,
#                'gene_type': 'protein_coding',
#                'length': 580,
#                'bed_CDS': (91, 580),
#                'bed_UTR_5': (0, 91)}},
#              'ENSG00000285509': {'ENST00000645041': {'exons': [(121045739,
#                  121045823),
#                 (121047528, 121047667),
#                 (121053551, 121053732),
#                 (121055052, 121055308),
#                 (121058345, 121058471),
#                 (121059969, 121060085),
#                 (121102665, 121102729),
#                 (121105831, 121105964),
#                 (121109211, 121109498),
#                 (121113072, 121113108)],
#                'CDS': [(121045739, 121045823, 0),
#                 (121047528, 121047667, 1),
#                 (121053551, 121053732, 2),
#                 (121055052, 121055308, 3),
#                 (121058345, 121058471, 4),
#                 (121059969, 121060085, 5),
#                 (121102665, 121102729, 6),
#                 (121105831, 121105964, 7),
#                 (121109211, 121109498, 8),
#                 (121113072, 121113108, 9)],
#                'strand': '+',
#                'start': 121045739,
#                'end': 121113108,
#                'gene_type': 'protein_coding',
#                'length': 1432,
#                'bed_CDS': (0, 1432)}},
#              'ENSG00000205592': {'ENST00000424466': {'exons': [(40528057,
#                  40528110),
#                 (40530458, 40530511),
#                 (40531057, 40531110),
#                 (40531209, 40531262),
#                 (40532029, 40532082),
#                 (40532229, 40532282),
#                 (40533025, 40533078),
#                 (40533233, 40533283),
#                 (40534156, 40534209),
#                 (40534711, 40534743),
#                 (40535013, 40535066),
#                 (40535204, 40535257),
#                 (40535765, 40535809),
#                 (40535906, 40535959),
#                 (40536440, 40536484),
#                 (40536923, 40536976),
#                 (40537396, 40537428),
#                 (40537662, 40537715),
#                 (40537854, 40537907),
#                 (40538794, 40538847),
#                 (40539529, 40539561),
#                 (40541619, 40541623)],
#                'CDS': [(40528057, 40528110, 0),
#                 (40530458, 40530511, 1),
#                 (40531057, 40531110, 2),
#                 (40531209, 40531262, 3),
#                 (40532029, 40532082, 4),
#                 (40532229, 40532282, 5),
#                 (40533025, 40533078, 6),
#                 (40533233, 40533283, 7),
#                 (40534156, 40534209, 8),
#                 (40534711, 40534743, 9),
#                 (40535013, 40535066, 10),
#                 (40535204, 40535257, 11),
#                 (40535765, 40535809, 12),
#                 (40535906, 40535959, 13),
#                 (40536440, 40536484, 14),
#                 (40536923, 40536976, 15),
#                 (40537396, 40537428, 16),
#                 (40537662, 40537715, 17),
#                 (40537854, 40537907, 18),
#                 (40538794, 40538847, 19),
#                 (40539529, 40539561, 20),
#                 (40541619, 40541623, 21)],
#                'strand': '+',
#                'start': 40528057,
#                'end': 40541623,
#                'gene_type': 'protein_coding',
#                'length': 1055,
#                'bed_CDS': (0, 1055)}},
#              'ENSG00000257411': {'ENST00000548861': {'exons': [(56101331,
#                  56101361),
#                 (56106588, 56106716),
#                 (56106990, 56107095),
#                 (56107187, 56107256),
#                 (56107521, 56107613),
#                 (56109230, 56109289)],
#                'CDS': [(56101340, 56101361, 0),
#                 (56106588, 56106716, 1),
#                 (56106990, 56107095, 2),
#                 (56107187, 56107256, 3),
#                 (56107521, 56107613, 4),
#                 (56109230, 56109289, 5)],
#                'strand': '+',
#                'start': 56101331,
#                'end': 56109289,
#                'gene_type': 'protein_coding',
#                'length': 489,
#                'bed_CDS': (9, 489),
#                'bed_UTR_5': (0, 9)}},
#              'ENSG00000144785': {'ENST00000549318': {'exons': [(56315821,
#                  56315943),
#                 (56315130, 56315242),
#                 (56314851, 56314966),
#                 (56311211, 56311414),
#                 (56310958, 56311054),
#                 (56309966, 56310029),
#                 (56300160, 56300220),
#                 (56286595, 56286645),
#                 (56285916, 56286023)],
#                'CDS': [(56315130, 56315217, 1),
#                 (56314851, 56314966, 2),
#                 (56311211, 56311414, 3),
#                 (56310958, 56311054, 4),
#                 (56309966, 56310029, 5),
#                 (56300160, 56300220, 6),
#                 (56286595, 56286645, 7),
#                 (56285916, 56286023, 8)],
#                'strand': '-',
#                'start': 56285916,
#                'end': 56315943,
#                'gene_type': 'protein_coding',
#                'length': 937,
#                'bed_CDS': (148, 937),
#                'bed_UTR_5': (0, 148)}},
#              'ENSG00000285625': {'ENST00000647707': {'exons': [(56741435,
#                  56741535),
#                 (56739294, 56739363),
#                 (56738434, 56738525),
#                 (56734147, 56734245),
#                 (56725263, 56725340),
#                 (56724452, 56724523),
#                 (56714612, 56714687)],
#                'CDS': [(56741435, 56741535, 0),
#                 (56739294, 56739363, 1),
#                 (56738434, 56738525, 2),
#                 (56734147, 56734245, 3),
#                 (56725263, 56725340, 4),
#                 (56724452, 56724523, 5),
#                 (56714612, 56714687, 6)],
#                'strand': '-',
#                'start': 56714612,
#                'end': 56741535,
#                'gene_type': 'protein_coding',
#                'length': 588,
#                'bed_CDS': (0, 588)}},
#              'ENSG00000257921': {'ENST00000546504': {'exons': [(57773053,
#                  57773128),
#                 (57783110, 57783283),
#                 (57783615, 57783652),
#                 (57786163, 57786247)],
#                'CDS': [(57773053, 57773128, 0),
#                 (57783110, 57783283, 1),
#                 (57783615, 57783652, 2),
#                 (57786163, 57786247, 3)],
#                'strand': '+',
#                'start': 57773053,
#                'end': 57786247,
#                'gene_type': 'protein_coding',
#                'length': 373,
#                'bed_CDS': (0, 373)}},
#              'ENSG00000257767': {'ENST00000546840': {'exons': [(111753890,
#                  111753915),
#                 (111755668, 111755745),
#                 (111781918, 111782022),
#                 (111783158, 111783298),
#                 (111785267, 111785346),
#                 (111789823, 111789934),
#                 (111790434, 111790562),
#                 (111791306, 111791418)],
#                'CDS': [(111753895, 111753915, 0),
#                 (111755668, 111755745, 1),
#                 (111781918, 111782022, 2),
#                 (111783158, 111783298, 3),
#                 (111785267, 111785346, 4),
#                 (111789823, 111789934, 5),
#                 (111790434, 111790562, 6),
#                 (111791306, 111791418, 7)],
#                'strand': '+',
#                'start': 111753890,
#                'end': 111791418,
#                'gene_type': 'protein_coding',
#                'length': 784,
#                'bed_CDS': (5, 784),
#                'bed_UTR_5': (0, 5)}},
#              'ENSG00000259371': {'ENST00000558325': {'exons': [(24120956,
#                  24120991),
#                 (24121365, 24121517),
#                 (24122971, 24123077),
#                 (24131276, 24131829)],
#                'CDS': [(24120956, 24120991, 0),
#                 (24121365, 24121517, 1),
#                 (24122971, 24123077, 2),
#                 (24131276, 24131829, 3)],
#                'strand': '+',
#                'start': 24120956,
#                'end': 24131829,
#                'gene_type': 'protein_coding',
#                'length': 850,
#                'bed_CDS': (0, 850)}},
#              'ENSG00000255526': {'ENST00000534348': {'exons': [(24232250,
#                  24232352),
#                 (24218384, 24218431),
#                 (24218133, 24218215),
#                 (24215552, 24215662),
#                 (24214492, 24214599),
#                 (24214310, 24214395),
#                 (24214096, 24214151)],
#                'CDS': [(24232250, 24232267, 0),
#                 (24218384, 24218431, 1),
#                 (24218133, 24218215, 2),
#                 (24215552, 24215662, 3),
#                 (24214492, 24214599, 4),
#                 (24214310, 24214395, 5),
#                 (24214096, 24214151, 6)],
#                'strand': '-',
#                'start': 24214096,
#                'end': 24232352,
#                'gene_type': 'protein_coding',
#                'length': 595,
#                'bed_CDS': (85, 595),
#                'bed_UTR_5': (0, 85)}},
#              'ENSG00000258466': {'ENST00000557564': {'exons': [(67690212,
#                  67690367),
#                 (67662477, 67662535),
#                 (67659864, 67659922)],
#                'CDS': [(67690212, 67690367, 0),
#                 (67662477, 67662535, 1),
#                 (67659864, 67659922, 2)],
#                'strand': '-',
#                'start': 67659864,
#                'end': 67690367,
#                'gene_type': 'protein_coding',
#                'length': 274,
#                'bed_CDS': (0, 274)}},
#              'ENSG00000259066': {'ENST00000557574': {'exons': [(93184993,
#                  93185032),
#                 (93186260, 93186482),
#                 (93209824, 93209957),
#                 (93210648, 93210708),
#                 (93212032, 93212127)],
#                'CDS': [(93186276, 93186482, 1),
#                 (93209824, 93209957, 2),
#                 (93210648, 93210708, 3),
#                 (93212032, 93212127, 4)],
#                'strand': '+',
#                'start': 93184993,
#                'end': 93212127,
#                'gene_type': 'protein_coding',
#                'length': 554,
#                'bed_CDS': (56, 554),
#                'bed_UTR_5': (0, 56)}},
#              'ENSG00000260170': {'ENST00000564080': {'exons': [(45587351,
#                  45587525),
#                 (45658907, 45659157),
#                 (45661955, 45662125),
#                 (45669928, 45669981),
#                 (45673607, 45673801),
#                 (45676101, 45676314)],
#                'CDS': [(45658924, 45659157, 1),
#                 (45661955, 45662125, 2),
#                 (45669928, 45669981, 3),
#                 (45673607, 45673801, 4),
#                 (45676101, 45676314, 5)],
#                'strand': '+',
#                'start': 45587351,
#                'end': 45676314,
#                'gene_type': 'protein_coding',
#                'length': 1060,
#                'bed_CDS': (192, 1060),
#                'bed_UTR_5': (0, 192)}},
#              'ENSG00000249240': {'ENST00000437723': {'exons': [(64841948,
#                  64842028),
#                 (64848593, 64848742),
#                 (64854921, 64855037),
#                 (64859894, 64859998),
#                 (64861477, 64861575),
#                 (64921921, 64922019),
#                 (64930822, 64930920)],
#                'CDS': [(64842017, 64842028, 0),
#                 (64848593, 64848742, 1),
#                 (64854921, 64855037, 2),
#                 (64859894, 64859998, 3),
#                 (64861477, 64861575, 4),
#                 (64921921, 64922019, 5),
#                 (64930822, 64930920, 6)],
#                'strand': '+',
#                'start': 64841948,
#                'end': 64930920,
#                'gene_type': 'protein_coding',
#                'length': 750,
#                'bed_CDS': (69, 750),
#                'bed_UTR_5': (0, 69)}},
#              'ENSG00000279765': {'ENST00000629685': {'exons': [(92883413,
#                  92883543),
#                 (92885515, 92885584),
#                 (92886169, 92886254),
#                 (92892004, 92892072),
#                 (92901167, 92901299),
#                 (92924321, 92924552),
#                 (92927244, 92927330)],
#                'CDS': [(92901238, 92901299, 4),
#                 (92924321, 92924552, 5),
#                 (92927244, 92927330, 6)],
#                'strand': '+',
#                'start': 92883413,
#                'end': 92927330,
#                'gene_type': 'protein_coding',
#                'length': 808,
#                'bed_CDS': (427, 808),
#                'bed_UTR_5': (0, 427)}},
#              'ENSG00000259784': {'ENST00000569317': {'exons': [(2513965,
#                  2514182),
#                 (2520984, 2521123),
#                 (2527561, 2527615),
#                 (2527773, 2527955)],
#                'CDS': [(2514104, 2514182, 0),
#                 (2520984, 2521123, 1),
#                 (2527561, 2527615, 2),
#                 (2527773, 2527955, 3)],
#                'strand': '+',
#                'start': 2513965,
#                'end': 2527955,
#                'gene_type': 'protein_coding',
#                'length': 596,
#                'bed_CDS': (139, 596),
#                'bed_UTR_5': (0, 139)}},
#              'ENSG00000260342': {'ENST00000567078': {'exons': [(18801431,
#                  18801519),
#                 (18798701, 18798834),
#                 (18797925, 18798044),
#                 (18795464, 18795581),
#                 (18794599, 18794683),
#                 (18788981, 18789118),
#                 (18788063, 18788142)],
#                'CDS': [(18801431, 18801466, 0),
#                 (18798701, 18798834, 1),
#                 (18797925, 18798044, 2),
#                 (18795464, 18795581, 3),
#                 (18794599, 18794683, 4),
#                 (18788981, 18789118, 5),
#                 (18788063, 18788142, 6)],
#                'strand': '-',
#                'start': 18788063,
#                'end': 18801519,
#                'gene_type': 'protein_coding',
#                'length': 764,
#                'bed_CDS': (53, 764),
#                'bed_UTR_5': (0, 53)}},
#              'ENSG00000261832': {'ENST00000637378': {'exons': [(28482626,
#                  28482634),
#                 (28482477, 28482545),
#                 (28482327, 28482382),
#                 (28482105, 28482198),
#                 (28466720, 28466902),
#                 (28462982, 28463081),
#                 (28462674, 28462869),
#                 (28458531, 28458591),
#                 (28458386, 28458421),
#                 (28456719, 28457026)],
#                'CDS': [(28482626, 28482634, 0),
#                 (28482477, 28482545, 1),
#                 (28482327, 28482382, 2),
#                 (28482105, 28482198, 3),
#                 (28466720, 28466902, 4),
#                 (28462982, 28463081, 5),
#                 (28462674, 28462869, 6),
#                 (28458531, 28458591, 7),
#                 (28458386, 28458421, 8),
#                 (28456719, 28457026, 9)],
#                'strand': '-',
#                'start': 28456719,
#                'end': 28482634,
#                'gene_type': 'protein_coding',
#                'length': 1112,
#                'bed_CDS': (0, 1112)}},
#              'ENSG00000277669': {'ENST00000449759': {'exons': [(29663279,
#                  29663316),
#                 (29679120, 29679210),
#                 (29694664, 29695144)],
#                'CDS': [(29679198, 29679210, 1), (29694664, 29695144, 2)],
#                'strand': '+',
#                'start': 29663279,
#                'end': 29695144,
#                'gene_type': 'protein_coding',
#                'length': 610,
#                'bed_CDS': (116, 610),
#                'bed_UTR_5': (0, 116)}},
#              'ENSG00000260869': {'ENST00000568114': {'exons': [(30557987,
#                  30558279),
#                 (30534227, 30534310)],
#                'CDS': [(30557987, 30558182, 0), (30534227, 30534310, 1)],
#                'strand': '-',
#                'start': 30534227,
#                'end': 30558279,
#                'gene_type': 'protein_coding',
#                'length': 377,
#                'bed_CDS': (97, 377),
#                'bed_UTR_5': (0, 97)}},
#              'ENSG00000259680': {'ENST00000569103': {'exons': [(33845184,
#                  33845229),
#                 (33844784, 33845086)],
#                'CDS': [(33845184, 33845229, 0), (33844784, 33845086, 1)],
#                'strand': '-',
#                'start': 33844784,
#                'end': 33845229,
#                'gene_type': 'protein_coding',
#                'length': 349,
#                'bed_CDS': (0, 349)}},
#              'ENSG00000260914': {'ENST00000570054': {'exons': [(69299682,
#                  69299774),
#                 (69316008, 69316119),
#                 (69316225, 69316372),
#                 (69318650, 69318711),
#                 (69318823, 69318942),
#                 (69319387, 69319543),
#                 (69320141, 69320289),
#                 (69320688, 69320769),
#                 (69321051, 69321270),
#                 (69322560, 69322700)],
#                'CDS': [(69299682, 69299774, 0),
#                 (69316008, 69316119, 1),
#                 (69316225, 69316372, 2),
#                 (69318650, 69318711, 3),
#                 (69318823, 69318942, 4),
#                 (69319387, 69319543, 5),
#                 (69320141, 69320289, 6),
#                 (69320688, 69320769, 7),
#                 (69321051, 69321270, 8),
#                 (69322560, 69322700, 9)],
#                'strand': '+',
#                'start': 69299682,
#                'end': 69322700,
#                'gene_type': 'protein_coding',
#                'length': 1284,
#                'bed_CDS': (0, 1284)}},
#              'ENSG00000260371': {'ENST00000563634': {'exons': [(69356209,
#                  69356306),
#                 (69336505, 69336712),
#                 (69335091, 69335348)],
#                'CDS': [(69356209, 69356210, 0),
#                 (69336505, 69336712, 1),
#                 (69335091, 69335348, 2)],
#                'strand': '-',
#                'start': 69335091,
#                'end': 69356306,
#                'gene_type': 'protein_coding',
#                'length': 564,
#                'bed_CDS': (96, 564),
#                'bed_UTR_5': (0, 96)}},
#              'ENSG00000261717': {'ENST00000566594': {'exons': [(75464468,
#                  75464552),
#                 (75414578, 75414695),
#                 (75412704, 75412754)],
#                'CDS': [(75464468, 75464552, 0),
#                 (75414578, 75414695, 1),
#                 (75412704, 75412754, 2)],
#                'strand': '-',
#                'start': 75412704,
#                'end': 75464552,
#                'gene_type': 'protein_coding',
#                'length': 254,
#                'bed_CDS': (0, 254)}},
#              'ENSG00000285471': {'ENST00000573619': {'exons': [(5772926,
#                  5773027),
#                 (5837181, 5837249),
#                 (5888757, 5888830),
#                 (5989930, 5990021),
#                 (6080371, 6080792)],
#                'CDS': [(6080659, 6080792, 4)],
#                'strand': '+',
#                'start': 5772926,
#                'end': 6080792,
#                'gene_type': 'protein_coding',
#                'length': 759,
#                'bed_CDS': (625, 759),
#                'bed_UTR_5': (0, 625)}},
#              'ENSG00000263620': {'ENST00000498285': {'exons': [(8162878,
#                  8162975),
#                 (8162249, 8162369),
#                 (8161608, 8161766),
#                 (8161473, 8161524),
#                 (8150816, 8150845)],
#                'CDS': [(8162878, 8162879, 0),
#                 (8162249, 8162369, 1),
#                 (8161608, 8161766, 2),
#                 (8161473, 8161524, 3),
#                 (8150816, 8150845, 4)],
#                'strand': '-',
#                'start': 8150816,
#                'end': 8162975,
#                'gene_type': 'protein_coding',
#                'length': 460,
#                'bed_CDS': (96, 460),
#                'bed_UTR_5': (0, 96)}},
#              'ENSG00000267261': {'ENST00000592574': {'exons': [(42154893,
#                  42154916),
#                 (42130337, 42130590),
#                 (42128649, 42128800),
#                 (42128261, 42128383),
#                 (42120706, 42120829),
#                 (42120225, 42120370),
#                 (42120030, 42120119),
#                 (42119674, 42119718)],
#                'CDS': [(42130337, 42130502, 1),
#                 (42128649, 42128800, 2),
#                 (42128261, 42128383, 3),
#                 (42120706, 42120829, 4),
#                 (42120225, 42120370, 5),
#                 (42120030, 42120119, 6),
# ...
#                'strand': '+',
#                'start': 41708612,
#                'end': 41761282,
#                'gene_type': 'protein_coding',
#                'length': 578,
#                'bed_CDS': (120, 578),
#                'bed_UTR_5': (0, 120)}},
#              'ENSG00000268643': {'ENST00000594664': {'exons': [(42254978,
#                  42255132),
#                 (42239955, 42240142),
#                 (42236858, 42236941),
#                 (42236606, 42236716),
#                 (42234583, 42234678)],
#                'CDS': [(42254978, 42254999, 0),
#                 (42239955, 42240142, 1),
#                 (42236858, 42236941, 2),
#                 (42236606, 42236716, 3),
#                 (42234583, 42234678, 4)],
#                'strand': '-',
#                'start': 42234583,
#                'end': 42255132,
#                'gene_type': 'protein_coding',
#                'length': 634,
#                'bed_CDS': (133, 634),
#                'bed_UTR_5': (0, 133)}},
#              'ENSG00000268361': {'ENST00000594374': {'exons': [(43592868,
#                  43593036),
#                 (43560910, 43561020),
#                 (43554692, 43554804)],
#                'CDS': [(43592868, 43593036, 0),
#                 (43560910, 43561020, 1),
#                 (43554692, 43554804, 2)],
#                'strand': '-',
#                'start': 43554692,
#                'end': 43593036,
#                'gene_type': 'protein_coding',
#                'length': 393,
#                'bed_CDS': (0, 393)}},
#              'ENSG00000267173': {'ENST00000588212': {'exons': [(44401568,
#                  44401608),
#                 (44397199, 44397256),
#                 (44340416, 44340539),
#                 (44336623, 44336718),
#                 (44329695, 44329936)],
#                'CDS': [(44397199, 44397213, 1),
#                 (44340416, 44340539, 2),
#                 (44336623, 44336718, 3),
#                 (44329695, 44329936, 4)],
#                'strand': '-',
#                'start': 44329695,
#                'end': 44401608,
#                'gene_type': 'protein_coding',
#                'length': 561,
#                'bed_CDS': (84, 561),
#                'bed_UTR_5': (0, 84)}},
#              'ENSG00000268434': {'ENST00000596586': {'exons': [(45785594,
#                  45785713),
#                 (45784641, 45784715),
#                 (45782193, 45782250),
#                 (45779778, 45779869),
#                 (45779471, 45779522)],
#                'CDS': [(45785594, 45785713, 0),
#                 (45784641, 45784715, 1),
#                 (45782193, 45782250, 2),
#                 (45779778, 45779869, 3),
#                 (45779471, 45779522, 4)],
#                'strand': '-',
#                'start': 45779471,
#                'end': 45785713,
#                'gene_type': 'protein_coding',
#                'length': 397,
#                'bed_CDS': (0, 397)}},
#              'ENSG00000268465': {'ENST00000595676': {'exons': [(48465837,
#                  48465957),
#                 (48470353, 48470500),
#                 (48470603, 48470669),
#                 (48472325, 48472431)],
#                'CDS': [(48470382, 48470500, 1),
#                 (48470603, 48470669, 2),
#                 (48472325, 48472431, 3)],
#                'strand': '+',
#                'start': 48465837,
#                'end': 48472431,
#                'gene_type': 'protein_coding',
#                'length': 443,
#                'bed_CDS': (150, 443),
#                'bed_UTR_5': (0, 150)}},
#              'ENSG00000267335': {'ENST00000604577': {'exons': [(49036703,
#                  49036885),
#                 (49023436, 49023603),
#                 (49023146, 49023200)],
#                'CDS': [(49036703, 49036711, 0),
#                 (49023436, 49023603, 1),
#                 (49023146, 49023200, 2)],
#                'strand': '-',
#                'start': 49023146,
#                'end': 49036885,
#                'gene_type': 'protein_coding',
#                'length': 406,
#                'bed_CDS': (174, 406),
#                'bed_UTR_5': (0, 174)}},
#              'ENSG00000283088': {'ENST00000634278': {'exons': [(52962727,
#                  52962768),
#                 (52895339, 52895435),
#                 (52894126, 52894220),
#                 (52893779, 52893856),
#                 (52891229, 52891346),
#                 (52890241, 52890328),
#                 (52888127, 52888253),
#                 (52880663, 52881983)],
#                'CDS': [(52890241, 52890255, 5),
#                 (52888127, 52888253, 6),
#                 (52880663, 52881983, 7)],
#                'strand': '-',
#                'start': 52880663,
#                'end': 52962768,
#                'gene_type': 'protein_coding',
#                'length': 1966,
#                'bed_CDS': (503, 1966),
#                'bed_UTR_5': (0, 503)}},
#              'ENSG00000268133': {'ENST00000597658': {'exons': [(57363566,
#                  57363703),
#                 (57368544, 57368579),
#                 (57371782, 57371908),
#                 (57398430, 57398584)],
#                'CDS': [(57368556, 57368579, 1),
#                 (57371782, 57371908, 2),
#                 (57398430, 57398584, 3)],
#                'strand': '+',
#                'start': 57363566,
#                'end': 57398584,
#                'gene_type': 'protein_coding',
#                'length': 456,
#                'bed_CDS': (150, 456),
#                'bed_UTR_5': (0, 150)}},
#              'ENSG00000269533': {'ENST00000596400': {'exons': [(57390008,
#                  57390114),
#                 (57394188, 57394223),
#                 (57417912, 57418038),
#                 (57419635, 57419994)],
#                'CDS': [(57390100, 57390114, 0),
#                 (57394188, 57394223, 1),
#                 (57417912, 57418038, 2),
#                 (57419635, 57419994, 3)],
#                'strand': '+',
#                'start': 57390008,
#                'end': 57419994,
#                'gene_type': 'protein_coding',
#                'length': 630,
#                'bed_CDS': (92, 630),
#                'bed_UTR_5': (0, 92)}},
#              'ENSG00000269026': {'ENST00000594684': {'exons': [(57682045,
#                  57682244),
#                 (57750785, 57750911),
#                 (57753291, 57753575)],
#                'CDS': [(57682212, 57682244, 0),
#                 (57750785, 57750911, 1),
#                 (57753291, 57753575, 2)],
#                'strand': '+',
#                'start': 57682045,
#                'end': 57753575,
#                'gene_type': 'protein_coding',
#                'length': 612,
#                'bed_CDS': (167, 612),
#                'bed_UTR_5': (0, 167)}},
#              'ENSG00000268750': {'ENST00000598031': {'exons': [(57819806,
#                  57819945),
#                 (57856104, 57856233),
#                 (57858576, 57858911)],
#                'CDS': [(57819913, 57819945, 0),
#                 (57856104, 57856233, 1),
#                 (57858576, 57858911, 2)],
#                'strand': '+',
#                'start': 57819806,
#                'end': 57858911,
#                'gene_type': 'protein_coding',
#                'length': 606,
#                'bed_CDS': (107, 606),
#                'bed_UTR_5': (0, 107)}},
#              'ENSG00000284776': {'ENST00000618693': {'exons': [(18567453,
#                  18567596),
#                 (18593731, 18593821),
#                 (18596006, 18596241),
#                 (18628127, 18628233),
#                 (18744100, 18744216)],
#                'CDS': [(18567479, 18567596, 0),
#                 (18593731, 18593821, 1),
#                 (18596006, 18596241, 2),
#                 (18628127, 18628233, 3),
#                 (18744100, 18744216, 4)],
#                'strand': '+',
#                'start': 18567453,
#                'end': 18744216,
#                'gene_type': 'protein_coding',
#                'length': 695,
#                'bed_CDS': (26, 695),
#                'bed_UTR_5': (0, 26)}},
#              'ENSG00000273154': {'ENST00000496820': {'exons': [(63735463,
#                  63735564),
#                 (63737845, 63737902),
#                 (63737973, 63738060),
#                 (63738183, 63738441)],
#                'CDS': [(63735463, 63735564, 0),
#                 (63737845, 63737902, 1),
#                 (63737973, 63738060, 2),
#                 (63738183, 63738441, 3)],
#                'strand': '+',
#                'start': 63735463,
#                'end': 63738441,
#                'gene_type': 'protein_coding',
#                'length': 507,
#                'bed_CDS': (0, 507)}},
#              'ENSG00000273047': {'ENST00000467211': {'exons': [(63738270,
#                  63738499),
#                 (63740377, 63740398)],
#                'CDS': [(63738270, 63738499, 0), (63740377, 63740398, 1)],
#                'strand': '+',
#                'start': 63738270,
#                'end': 63740398,
#                'gene_type': 'protein_coding',
#                'length': 252,
#                'bed_CDS': (0, 252)}},
#              'ENSG00000265590': {'ENST00000431216': {'exons': [(32612105,
#                  32612146),
#                 (32609838, 32610005),
#                 (32607649, 32607716),
#                 (32604125, 32604283),
#                 (32603161, 32603292),
#                 (32602272, 32602367),
#                 (32582200, 32582415),
#                 (32578822, 32578831)],
#                'CDS': [(32612105, 32612146, 0),
#                 (32609838, 32610005, 1),
#                 (32607649, 32607716, 2),
#                 (32604125, 32604283, 3),
#                 (32603161, 32603292, 4),
#                 (32602272, 32602367, 5),
#                 (32582200, 32582415, 6),
#                 (32578822, 32578831, 7)],
#                'strand': '-',
#                'start': 32578822,
#                'end': 32612146,
#                'gene_type': 'protein_coding',
#                'length': 891,
#                'bed_CDS': (0, 891)}},
#              'ENSG00000249624': {'ENST00000433395': {'exons': [(33246774,
#                  33246890),
#                 (33248709, 33248854),
#                 (33252662, 33252830),
#                 (33268394, 33268517),
#                 (33276596, 33276753),
#                 (33279752, 33279918),
#                 (33283094, 33283212)],
#                'CDS': [(33246774, 33246890, 0),
#                 (33248709, 33248854, 1),
#                 (33252662, 33252830, 2),
#                 (33268394, 33268517, 3),
#                 (33276596, 33276753, 4),
#                 (33279752, 33279918, 5),
#                 (33283094, 33283212, 6)],
#                'strand': '+',
#                'start': 33246774,
#                'end': 33283212,
#                'gene_type': 'protein_coding',
#                'length': 1000,
#                'bed_CDS': (0, 1000)}},
#              'ENSG00000249209': {'ENST00000429238': {'exons': [(33931471,
#                  33931607),
#                 (33915728, 33915977),
#                 (33914450, 33914500),
#                 (33912289, 33912399),
#                 (33909082, 33909211),
#                 (33907341, 33907453),
#                 (33585978, 33586181),
#                 (33584687, 33584768)],
#                'CDS': [(33915728, 33915763, 1),
#                 (33914450, 33914500, 2),
#                 (33912289, 33912399, 3),
#                 (33909082, 33909211, 4),
#                 (33907341, 33907453, 5),
#                 (33585978, 33586181, 6),
#                 (33584687, 33584768, 7)],
#                'strand': '-',
#                'start': 33584687,
#                'end': 33931607,
#                'gene_type': 'protein_coding',
#                'length': 1078,
#                'bed_CDS': (351, 1078),
#                'bed_UTR_5': (0, 351)}},
#              'ENSG00000275113': {'ENST00000621907': {'exons': [(49341192,
#                  49341255),
#                 (49342296, 49342387),
#                 (49342853, 49342973),
#                 (49345797, 49345922)],
#                'CDS': [(49342304, 49342387, 1),
#                 (49342853, 49342973, 2),
#                 (49345797, 49345922, 3)],
#                'strand': '+',
#                'start': 49341192,
#                'end': 49345922,
#                'gene_type': 'protein_coding',
#                'length': 403,
#                'bed_CDS': (72, 403),
#                'bed_UTR_5': (0, 72)}},
#              'ENSG00000285547': {'ENST00000648922': {'exons': [(72572651,
#                  72572843),
#                 (72572057, 72572109),
#                 (72568754, 72568884),
#                 (72567889, 72568030),
#                 (72495156, 72495268),
#                 (72490929, 72491006),
#                 (72488933, 72489041),
#                 (72464559, 72464731),
#                 (72462004, 72462098),
#                 (72351733, 72351838),
#                 (72302810, 72302934),
#                 (72301811, 72302244)],
#                'CDS': [(72572651, 72572761, 0),
#                 (72572057, 72572109, 1),
#                 (72568754, 72568884, 2),
#                 (72567889, 72568030, 3),
#                 (72495156, 72495268, 4),
#                 (72490929, 72491006, 5),
#                 (72488933, 72489041, 6),
#                 (72464559, 72464731, 7),
#                 (72462004, 72462098, 8),
#                 (72351733, 72351838, 9),
#                 (72302810, 72302934, 10),
#                 (72301811, 72302244, 11)],
#                'strand': '-',
#                'start': 72301811,
#                'end': 72572843,
#                'gene_type': 'protein_coding',
#                'length': 1752,
#                'bed_CDS': (82, 1752),
#                'bed_UTR_5': (0, 82)}},
#              'ENSG00000198888': {'ENST00000361390': {'exons': [(3307, 4262)],
#                'CDS': [(3307, 4262, 0)],
#                'strand': '+',
#                'start': 3307,
#                'end': 4262,
#                'gene_type': 'protein_coding',
#                'length': 956,
#                'bed_CDS': (0, 956)}},
#              'ENSG00000198763': {'ENST00000361453': {'exons': [(4470, 5511)],
#                'CDS': [(4470, 5511, 0)],
#                'strand': '+',
#                'start': 4470,
#                'end': 5511,
#                'gene_type': 'protein_coding',
#                'length': 1042,
#                'bed_CDS': (0, 1042)}},
#              'ENSG00000198804': {'ENST00000361624': {'exons': [(5904, 7445)],
#                'CDS': [(5904, 7445, 0)],
#                'strand': '+',
#                'start': 5904,
#                'end': 7445,
#                'gene_type': 'protein_coding',
#                'length': 1542,
#                'bed_CDS': (0, 1542)}},
#              'ENSG00000198938': {'ENST00000362079': {'exons': [(9207, 9990)],
#                'CDS': [(9207, 9990, 0)],
#                'strand': '+',
#                'start': 9207,
#                'end': 9990,
#                'gene_type': 'protein_coding',
#                'length': 784,
#                'bed_CDS': (0, 784)}},
#              'ENSG00000198840': {'ENST00000361227': {'exons': [(10059, 10404)],
#                'CDS': [(10059, 10404, 0)],
#                'strand': '+',
#                'start': 10059,
#                'end': 10404,
#                'gene_type': 'protein_coding',
#                'length': 346,
#                'bed_CDS': (0, 346)}},
#              'ENSG00000198886': {'ENST00000361381': {'exons': [(10760, 12137)],
#                'CDS': [(10760, 12137, 0)],
#                'strand': '+',
#                'start': 10760,
#                'end': 12137,
#                'gene_type': 'protein_coding',
#                'length': 1378,
#                'bed_CDS': (0, 1378)}},
#              'ENSG00000198695': {'ENST00000361681': {'exons': [(14149, 14673)],
#                'CDS': [(14149, 14673, 0)],
#                'strand': '-',
#                'start': 14149,
#                'end': 14673,
#                'gene_type': 'protein_coding',
#                'length': 525,
#                'bed_CDS': (0, 525)}},
#              'ENSG00000198727': {'ENST00000361789': {'exons': [(14747, 15887)],
#                'CDS': [(14747, 15887, 0)],
#                'strand': '+',
#                'start': 14747,
#                'end': 15887,
#                'gene_type': 'protein_coding',
#                'length': 1141,
#                'bed_CDS': (0, 1141)}}})

# %% [markdown]
# When we examined these genes on UCSC browser, we saw they were overlapping with other genes and they didn't have a 3UTR.
#
# We decided to take them out as well.
#
# Now we narrowed down our set to
# `transcripts_with_stop_codon`

# %%
t_fasta_stream = FastaFile(transcripts_fasta)

start_triplets = defaultdict(int)
stop_triplets = defaultdict(int)

for this_fasta_entry in t_fasta_stream:
    contents = this_fasta_entry.header.strip().split("|")
    this_t = contents[0].split(".")[0]
    
    g_contents = contents[1].split(".")
    this_g = g_contents[0]
    if len(g_contents) >= 2 and "PAR_Y" in g_contents[1]:
        continue
    
    transcripts = transcripts_with_stop_codon.get(this_g, None)
    if transcripts == None:
        continue
    if bed_CDS == None:
        continue
    if this_t in list(transcripts_with_stop_codon[this_g].keys()):
        bed_CDS = transcripts_with_stop_codon[this_g][this_t].get("bed_CDS", None)
        
        if bed_CDS != None:
            start_codon_coord = bed_CDS[0]
            start_triplets[ this_fasta_entry.sequence[ start_codon_coord:start_codon_coord+3 ]  ] += 1
            observed_stop_triplet = this_fasta_entry.sequence[ bed_CDS[1]:bed_CDS[1] + 3 ]
            stop_triplets[ observed_stop_triplet ] += 1
            
print(start_triplets)
print("---------------------------")
print(stop_triplets)
# Out:
# defaultdict(<class 'int'>, {'ATG': 19647, 'GTG': 7, 'AGG': 3, 'AAG': 9, 'GCT': 4, 'GAA': 4, 'CTG': 22, 'GGT': 1, 'GGG': 6, 'CTC': 3, 'GGA': 5, 'CTT': 3, 'AGT': 3, 'GCG': 4, 'CAG': 4, 'AGC': 5, 'TTC': 1, 'GCC': 4, 'ACT': 2, 'TTG': 3, 'ATC': 4, 'TGA': 3, 'ATA': 2, 'ATT': 6, 'TCC': 7, 'CAC': 2, 'ACG': 2, 'TAA': 1, 'AGA': 5, 'GTA': 1, 'TCT': 2, 'GAG': 1, 'CTA': 1, 'ACC': 1, 'CCT': 4, 'CAA': 3, 'CGG': 1, 'GAT': 4, 'AAC': 2, 'TAT': 1, 'TTA': 1, 'TTT': 1, 'GTC': 1, 'AAA': 1, 'GTT': 2, 'TCA': 3, 'TGG': 3, 'CCA': 3, 'CGC': 3, 'GGC': 2, 'ACA': 3, 'CCG': 2, 'GAC': 1, 'TAC': 1, 'CGT': 1, 'AAT': 1})
# ---------------------------
# defaultdict(<class 'int'>, {'TAG': 4415, 'TAA': 5625, 'TGA': 9782})

# %%
len(transcripts_with_stop_codon)
# Out:
# 19822

# %%
CDS_remainder_by_3 = [0,0,0]
non_zero_remainder_transcripts = defaultdict(dict)

for g, transcripts in transcripts_with_stop_codon.items():
    for t_name, t_contents in transcripts.items():
        bed_CDS = t_contents.get("bed_CDS", None)
        this_remainder = (bed_CDS[1] - bed_CDS[0]) % 3
        CDS_remainder_by_3[this_remainder] += 1
        if this_remainder != 0:
            non_zero_remainder_transcripts[g][t_name] = t_contents

print("CDS length divisible by 3: ", CDS_remainder_by_3[0])
print("CDS length NOT divisible by 3: ", CDS_remainder_by_3[1] + CDS_remainder_by_3[2])
# Out:
# CDS length divisible by 3:  19734
# CDS length NOT divisible by 3:  88

# %% [markdown]
# ### 3. CDS Regions
#
# We check whether different transcripts of the same gene of the Appris list have different CDS sequence or not.

# %%
t_fasta_stream = FastaFile(transcripts_fasta)
selected_CDS_sequences = defaultdict(dict)
different_CDS_transcripts = list()

for this_fasta_entry in t_fasta_stream:
    contents = this_fasta_entry.header.strip().split("|")
    this_t = contents[0].split(".")[0]
    
    g_contents = contents[1].split(".")
    this_g = g_contents[0]
    if len(g_contents) >= 2 and "PAR_Y" in g_contents[1]:
        continue
    
    pre_transcripts = transcripts_with_stop_codon.get(this_g, None)
    if pre_transcripts == None or pre_transcripts == {}:
        continue
    
    transcripts = appris_principal_transcripts.get(this_g, {})
    if this_t not in transcripts.keys():
        continue
    cds_boundaries = transcripts[this_t]["bed_CDS"]
    
    selected_CDS_sequences[this_g][this_t] = this_fasta_entry.sequence[ cds_boundaries[0]: cds_boundaries[1] ]
                 
for g, transcripts in selected_CDS_sequences.items():
    
    transcript_items = list(transcripts.items ())
    first_t, first_t_cds = transcript_items[0] 
    
    for t_name, t_cds in transcript_items[1:]:
        if t_cds != first_t_cds:
            different_CDS_transcripts.append( (first_t, t_name, first_t_cds, t_cds) )

# %%
for e in different_CDS_transcripts:
    print( e[0], e[1], len(e[2]), len(e[3]) )
# Out:
# ENST00000619410 ENST00000621965 5046 5046
# ENST00000612898 ENST00000396980 378 378
# ENST00000369393 ENST00000629399 16788 16788
# ENST00000242257 ENST00000440306 738 738
# ENST00000369701 ENST00000369699 3666 3666
# ENST00000358056 ENST00000616146 426 426
# ENST00000393066 ENST00000262294 2892 2892
# ENST00000328041 ENST00000613834 1932 1932

# %% [markdown]
# Interestingly, all different cds sequences have the same length. When we looked at the second item (ENST00000612898 ENST00000396980 378 378), the seuqneces looked almost identical. So we look at them nuc-by-nuc.

# %% [markdown]
# So, these two sequences at only one place (index 377).
#
# We look at the longest sequence as well

# %%
def find_disagreeing_indices( seq_1, seq_2 ):
    disagreeing_indices = []
    
    for i in range( len(seq_1) ):
        if seq_1[i] != seq_2[i]:
            disagreeing_indices.append(i) 
    
    return disagreeing_indices

# %%
for e in different_CDS_transcripts:
    print( find_disagreeing_indices( e[2], e[3] ) )
# Out:
# [353]
# [377]
# [9878]
# [5]
# [621, 622, 624, 625, 626]
# [200]
# [2891]
# [269]

# %% [markdown]
# Hence, appris principal transcripts have identical CDS. There are very few exceptions to this, coming from the above output. But, for mapping purposes this won't result in an important difference.

# %% [markdown]
# ### 4. CDS Length Distirbution

# %%
cds_lengths = []
gene_lengths = []

for g, transcripts in transcripts_with_stop_codon.items():
    for t_name, t_contents in transcripts.items():
        cds_lengths.append( t_contents["bed_CDS"][1] - t_contents["bed_CDS"][0] )
        gene_lengths.append(t_contents["length"])
    
len(cds_lengths)
# Out:
# 19822

# %%
import numpy as np

# %%
cds_lengths_np = np.array(cds_lengths, dtype= np.int)
gene_lengths_np = np.array(gene_lengths, dtype= np.int)

# %%
np.mean(cds_lengths)
# Out:
# 1696.91615376854

# %%
np.median(cds_lengths)
# Out:
# 1269.0

# %% [markdown]
# According to Karlin et. al.
# [https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1150220/](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1150220/),
# the median size of a human protein is 375 peptides = 1125 nucleotides
#
# This is close to (1269) what we got for our selected transcripts.

# %% [markdown]
# ## Summary & Conclusion
#
# We explored [Appris](https://academic.oup.com/nar/article/46/D1/D213/4561658) transcripts. Based on our observations, we decided to filter out some transcripts for our purposes. In particular, we followed the following steps:
#
# 1. We picked only "PRINCIPAL" entries and left "ALTERNATIVE" entries.
# 2. We picked only protein coding genes by choosing "gene_type protein_coding" in the GTF file
# 3. We excluded transcripts that didn't have 3TR and hence a stop codon.
#
# These steps are mostly based on our 'Sanity Checks'.
#
# Also, we discard Y chromosome paralogs of genes. They have "PAR_Y" in their gene ID in the gtf file and the fasta file
#
# After filtering, we had a total of 19822 transcripts.
#
# * 19734 of these transcripts have CDS with length a multiple of 3. 88 of them don't.
# * 19647 of them start with ATG (the start codon)
# * All of the transcripts have proper stop codons
# * All appris genes have identical CDS regions. However there are 8 exceptions to this. We found 8 cases where the transcripts have the same CDS length but differ in a few places. You can find the complete list above.
# * The median length of the CDS regiosn is 1269. This is consistent with the median length of human proteins.

# %% [markdown]
# ## Files and Hash Sums
#
# Appris Version 2018_12.v28
#
# Appris list was downloaded from : http://appris-tools.org/#/downloads
# on January 17 2019
#
# GENCODE:
#
# All other files have been downloaded from gencode website: [https://www.gencodegenes.org/human/](https://www.gencodegenes.org/human/)
#
# Version: Release 29 (GRCh38.p12)

# %%
! zcat  ../raw/sequence/gencode.v29.transcripts.fa.gz | md5sum
# Out:
# 69765772b5a30104dd3874d82919be9f  -

# %%
! zcat ../raw/annotation/gencode.v29.annotation.gtf.gz | md5sum
# Out:
# 737c63114c6d9cf1678a863e9087d179  -

# %%
! zcat ../raw/annotation/appris_data.principal.txt.gz | md5sum
# Out:
# 28280c63e87392a3e1732c11cb4e3604  -

# %% [markdown]
# ## Generating RiboFlow Reference and Annotation
#
# If the riboflow reference and annotation has not already been generated, you can run the 'generate_riboflow_ref_and_annot.sh' inside the scripts folder.
